# %% [markdown]
# !ls "/content/drive/My Drive/"
# !pip install -q keras

# %%
# !pip install -q keras

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/cnn_keras.py"
# Out:
# Using TensorFlow backend.
# 2020-05-16 06:16:28.833950: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# entered
# /content/drive/My Drive/Colab Notebooks/cifar-10-batches-py/
# Handing file: test_batch
# Handing file: data_batch_3
# Handing file: data_batch_2
# Handing file: data_batch_5
# Handing file: data_batch_1
# Handing file: data_batch_4
# now (50000, 32, 32, 3)
# (50000, 10)
# (10000, 32, 32, 3)
# (10000, 10)
# 2020-05-16 06:16:31.564715: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-16 06:16:31.597675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-16 06:16:31.598222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...
